# %% [markdown]
# # Team X
# ### Empowering the nation in the fight against crime
#
# Fighters: Sanchit Bareja, Kush Agrawal

# %% [markdown]
# 0. Merge all data
# 1. Filter 3-1-1 reports (based on category)
# 2. Create training and test sets (can use a smaller set first initially)
# 2. Approach 1: Create bag-of-words model using descript to classify into emergency/non-emergency
# 3. Approach 2: Look at pd-district as use them as features as well along with the bag-of-words model
# 4. Look into model and see which words really sway me to classify something as an emergeny
#
# 3-1-1 data is a separate report.

# %%
from pylab import *
# %matplotlib inline
import pandas as pd

df = pd.read_csv("/Users/pedropinto/Documents/Sanchit/Personal/project/sfpd_incident_2008_2014.csv",
                     na_values=['-'], low_memory=False)
cs = pd.read_csv("/Users/pedropinto/Documents/Sanchit/Personal/project/Case_Data_from_San_Francisco_311__SF311_.csv",
                    na_values=['NaN'], low_memory=False)

# %%
df.head(2)
# Out:
#    Unnamed: 0  IncidntNum        Category  \
# 0           0    80000406         ASSAULT
# 1           1    80000406  OTHER OFFENSES
#
#                               Descript DayOfWeek        Date   Time  \
# 0                 THREATS AGAINST LIFE   Tuesday  01/01/2008  00:45
# 1  INJURY TO TELEGRAPH/TELEPHONE LINES   Tuesday  01/01/2008  00:45
#
#   PdDistrict      Resolution                  Location           X          Y
# 0    TARAVAL  ARREST, BOOKED  0.0 Block of HOLLOWAY AV -122.454091  37.721818
# 1    TARAVAL  ARREST, BOOKED  0.0 Block of HOLLOWAY AV -122.454091  37.721818
#
# [2 rows x 12 columns]

# %%
cs.head(2)
# Out:
#     CaseID                  Opened Closed                 Updated Status  \
# 0  4232724  11/22/2014 12:37:48 AM    NaN  11/22/2014 12:37:48 AM   Open
# 1  4232702  11/22/2014 12:12:25 AM    NaN  11/22/2014 12:14:54 AM   Open
#
#    Responsible Agency                      Category  \
# 0  Recology_Abandoned  Street and Sidewalk Cleaning
# 1       RPD NSA Queue         Rec and Park Requests
#
#                     Request Type Request Details  \
# 0                Illegal_Dumping       Furniture
# 1  Park - Structural_Maintenance           Other
#
#                                          Address  Supervisor District  \
# 0        1264 GROVE ST, SAN FRANCISCO, CA, 94117                    5
# 1  Intersection of COLERIDGE ST and VIRGINIA AVE                    9
#
#        Neighborhood                                  Point    Source  \
# 0  Western Addition         (37.776108601, -122.437423948)   Open311
# 1    Bernal Heights  (37.7426787523838, -122.420386857945)  Voice In
#
#                                            Media URL
# 0  http://mobile311.sfgov.org/media/san_francisco...
# 1                                                NaN
#
# [2 rows x 15 columns]

# %%
# Using Address for exact match

a = pd.merge(df, cs, how='inner', on=None, left_on='Location', right_on='Address', 
          left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True)
a.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, IncidntNum, Category_x, Descript, DayOfWeek, Date, Time, PdDistrict, Resolution, Location, X, Y, CaseID, Opened, Closed, Updated, Status, Responsible Agency, Category_y, Request Type, Request Details, Address, Supervisor District, Neighborhood, Point, Source, Media URL]
# Index: []
#
# [0 rows x 27 columns]

# %%
df['DateTime'] = pd.to_datetime(df.apply(lambda row: row['Date'] + ' ' + row['Time'], axis=1))

# %%
cs['DateTime'] = pd.to_datetime(cs.apply(lambda row: row['Opened'], axis=1))

# %%
b = pd.merge(df, cs, how='inner', on=None, left_on='DateTime', right_on='DateTime', 
          left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True)
b.head()
# Out:
#    Unnamed: 0  IncidntNum     Category_x  \
# 0       67271    86071302  LARCENY/THEFT
# 1       67272    81321663          FRAUD
# 2       67273    90959495   NON-CRIMINAL
# 3       67280    81047085       BURGLARY
# 4       67281    81046231       BURGLARY
#
#                                       Descript  DayOfWeek        Date   Time  \
# 0                      GRAND THEFT OF PROPERTY  Wednesday  10/01/2008  07:00
# 1                 FALSE PRETENSES, GRAND THEFT  Wednesday  10/01/2008  07:00
# 2                                LOST PROPERTY  Wednesday  10/01/2008  07:00
# 3  BURGLARY OF APARTMENT HOUSE, FORCIBLE ENTRY  Wednesday  10/01/2008  07:45
# 4  BURGLARY OF APARTMENT HOUSE, UNLAWFUL ENTRY  Wednesday  10/01/2008  07:45
#
#   PdDistrict Resolution                         Location           X  \
# 0   SOUTHERN       NONE             TOWNSEND ST / 4TH ST -122.394986
# 1   RICHMOND       NONE            500.0 Block of 6TH AV -122.464185
# 2    TARAVAL       NONE        200.0 Block of MONTANA ST -122.459786
# 3    MISSION       NONE  3700.0 Block of CESAR CHAVEZ ST -122.422790
# 4    TARAVAL       NONE      2700.0 Block of SAN JOSE AV -122.452393
#
#            Y            DateTime  CaseID                  Opened  \
# 0  37.777091 2008-10-01 07:00:00  290291  10/01/2008 07:00:00 AM
# 1  37.777709 2008-10-01 07:00:00  290291  10/01/2008 07:00:00 AM
# 2  37.716707 2008-10-01 07:00:00  290291  10/01/2008 07:00:00 AM
# 3  37.747956 2008-10-01 07:45:00  290308  10/01/2008 07:45:00 AM
# 4  37.713918 2008-10-01 07:45:00  290308  10/01/2008 07:45:00 AM
#
#                    Closed                 Updated  Status  \
# 0                     NaN  11/25/2008 09:36:00 AM    Open
# 1                     NaN  11/25/2008 09:36:00 AM    Open
# 2                     NaN  11/25/2008 09:36:00 AM    Open
# 3  10/02/2008 06:07:00 AM  10/02/2008 06:07:00 AM  Closed
# 4  10/02/2008 06:07:00 AM  10/02/2008 06:07:00 AM  Closed
#
#            Responsible Agency          Category_y
# 0  DPT SignShop - DO NOT USE!         Sign Repair ...
# 1  DPT SignShop - DO NOT USE!         Sign Repair ...
# 2  DPT SignShop - DO NOT USE!         Sign Repair ...
# 3               DPW Ops Queue  Litter Receptacles ...
# 4               DPW Ops Queue  Litter Receptacles ...
#
# [5 rows x 28 columns]

# %%
def split_point(point):
    if point:
        try:
            point_split = point[1:-1].split(",")
            X = float(point_split[0])
            Y = float(point_split[1])
            return (X, Y)
        except:
            return (0.0,0.0)
    else:
        return (0.0,0.0)

def get_X(point):
    return split_point(point['Point'])[0]

def get_Y(point):
    return split_point(point['Point'])[1]

cs['X'] = cs.apply(get_X, axis=1)
cs['Y'] = cs.apply(get_Y, axis=1)

# %%
cs.head()
# Out:
#     CaseID                  Opened                  Closed  \
# 0  4232724  11/22/2014 12:37:48 AM                     NaN
# 1  4232702  11/22/2014 12:12:25 AM                     NaN
# 2  4232685  11/21/2014 11:40:32 PM                     NaN
# 3  4232663  11/21/2014 11:12:55 PM  11/22/2014 12:30:42 AM
# 4  4232642  11/21/2014 10:52:50 PM                     NaN
#
#                   Updated  Status             Responsible Agency  \
# 0  11/22/2014 12:37:48 AM    Open             Recology_Abandoned
# 1  11/22/2014 12:14:54 AM    Open                  RPD NSA Queue
# 2  11/21/2014 11:40:32 PM    Open  Clear Channel - Transit Queue
# 3  11/22/2014 12:30:42 AM  Closed                PUC - Water - G
# 4  11/21/2014 10:59:48 PM    Open                311 HA SR Queue
#
#                        Category                               Request Type  \
# 0  Street and Sidewalk Cleaning                            Illegal_Dumping
# 1         Rec and Park Requests              Park - Structural_Maintenance
# 2      Graffiti Public Property  Not_Offensive Graffiti on Public Property
# 3                  Sewer Issues                                 Water_leak
# 4                 SFHA Requests                  SFHA Priority - Emergency
#
#                             Request Details  \
# 0                                 Furniture
# 1                                     Other
# 2  Transit_Shelter_Platform - Not_Offensive
# 3                                     Other
# 4                                  Plumbers
#
#                                          Address  Supervisor District  \
# 0        1264 GROVE ST, SAN FRANCISCO, CA, 94117                    5
# 1  Intersection of COLERIDGE ST and VIRGINIA AVE                    9
# 2          845 BUSH ST, SAN FRANCISCO, CA, 94108                    3
# 3        2254 34TH AVE, SAN FRANCISCO, CA, 94116                    4
# 4     1004 GRIFFITH ST, SAN FRANCISCO, CA, 94124                   10
#
#             Neighborhood                                  Point    Source  \
# 0       Western Addition         (37.776108601, -122.437423948)   Open311
# 1         Bernal Heights  (37.7426787523838, -122.420386857945)  Voice In
# 2  Downtown/Civic Center   (37.789801581238, -122.411164694153)   Open311
# 3               Parkside   (37.745048782641, -122.491801186923)  Voice In
# 4                Bayview    (37.72891753531, -122.378627366509)  Voice In
#
#                                            Media URL            DateTime  \
# 0  http://mobile311.sfgov.org/media/san_francisco... 2014-11-22 00:37:48
# 1                                                NaN 2014-11-22 00:12:25
# 2                                                NaN 2014-11-21 23:40:32
# 3                                                NaN 2014-11-21 23:12:55
# 4                                                NaN 2014-11-21 22:52:50
#
#            X           Y
# 0  37.776109 -122.437424
# 1  37.742679 -122.420387
# 2  37.789802 -122.411165
# 3  37.745049 -122.491801
# 4  37.728918 -122.378627
#
# [5 rows x 18 columns]

# %%
# 1 ft corresponds to 0.000002746181435 degree shift in lat/long
# 1 block is roughly 500 ft in SF
# 1 block is roughly 0.001373090717 degree shift in both lat/long
import math, datetime
block_norm = 0.001373090717/4
time_block = 300 # 5 mins

def normalize_lat(lat):
    lat_blocks = float(lat-37)/block_norm
    return math.floor(lat_blocks)

def normalize_long(longt):
    longt_blocks = float(longt-(-123))/block_norm
    return math.floor(longt_blocks)

def add_lat_long_blocks(row):
    return normalize_lat(float(row['X']))+normalize_long(float(row['Y']))

def normalize_datetime(row):
    try:
        datetime_row = row['DateTime']
        a = (datetime_row - datetime.datetime(1970,1,1)).total_seconds()
        five_blocks = math.floor(float(a)/float(time_block))
        return five_blocks
    except:
        return 0.0

df['time_vicinity'] = df.apply(normalize_datetime, axis=1)
cs['time_vicinity'] = cs.apply(normalize_datetime, axis=1)
df['block_vicinity'] = df.apply(add_lat_long_blocks, axis=1)
cs['block_vicinity'] = cs.apply(add_lat_long_blocks, axis=1)

# %%
def add_latlng_datetime(row):
    return str(row['time_vicinity'])+' '+str(row['block_vicinity'])

df['latlng_datetime'] = df.apply(add_latlng_datetime, axis=1)
cs['latlng_datetime'] = cs.apply(add_latlng_datetime, axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  IncidntNum        Category  \
# 0           0    80000406         ASSAULT
# 1           1    80000406  OTHER OFFENSES
# 2           2    80000230  SUSPICIOUS OCC
# 3           3    86000577  OTHER OFFENSES
# 4           4    86014299    NON-CRIMINAL
#
#                               Descript DayOfWeek        Date   Time  \
# 0                 THREATS AGAINST LIFE   Tuesday  01/01/2008  00:45
# 1  INJURY TO TELEGRAPH/TELEPHONE LINES   Tuesday  01/01/2008  00:45
# 2                    SUSPICIOUS PERSON   Tuesday  01/01/2008  00:48
# 3               OBSCENE PHONE CALLS(S)   Tuesday  01/01/2008  00:50
# 4                        LOST PROPERTY   Tuesday  01/01/2008  00:50
#
#   PdDistrict      Resolution                    Location           X  \
# 0    TARAVAL  ARREST, BOOKED    0.0 Block of HOLLOWAY AV -122.454091
# 1    TARAVAL  ARREST, BOOKED    0.0 Block of HOLLOWAY AV -122.454091
# 2    TARAVAL   ARREST, CITED  100.0 Block of SAGAMORE ST -122.457207
# 3   SOUTHERN            NONE    800.0 Block of BRYANT ST -122.403743
# 4    MISSION            NONE      100.0 Block of UTAH ST -122.406735
#
#            Y            DateTime  block_vicinity   latlng_datetime  \
# 0  37.721818 2008-01-01 00:45:00            3692  3997161.0 3692.0
# 1  37.721818 2008-01-01 00:45:00            3692  3997161.0 3692.0
# 2  37.711290 2008-01-01 00:48:00            3652  3997161.0 3652.0
# 3  37.775232 2008-01-01 00:50:00            3995  3997162.0 3995.0
# 4  37.768172 2008-01-01 00:50:00            3965  3997162.0 3965.0
#
#    time_vicinity
# 0        3997161
# 1        3997161
# 2        3997161
# 3        3997162
# 4        3997162
#
# [5 rows x 16 columns]

# %%
c = pd.merge(df, cs, how='inner', on=None, left_on='latlng_datetime', right_on='latlng_datetime', 
          left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True)
c.head()
# Out:
#    Unnamed: 0  IncidntNum      Category_x                      Descript  \
# 0       67502    81048287  SUSPICIOUS OCC         SUSPICIOUS OCCURRENCE
# 1       67548    81045675  OTHER OFFENSES             TRAFFIC VIOLATION
# 2       67558    81045794  OTHER OFFENSES             TRAFFIC VIOLATION
# 3       68462    86073433   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4       69491    81064675    NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED
#
#    DayOfWeek        Date   Time  PdDistrict         Resolution  \
# 0  Wednesday  10/01/2008  14:00  TENDERLOIN               NONE
# 1  Wednesday  10/01/2008  15:28     MISSION      ARREST, CITED
# 2  Wednesday  10/01/2008  15:54     MISSION      ARREST, CITED
# 3     Friday  10/03/2008  22:15    SOUTHERN               NONE
# 4     Monday  10/06/2008  09:59  TENDERLOIN  PSYCHOPATHIC CASE
#
#                       Location         X_x        Y_x          DateTime_x  \
# 0           EDDY ST / JONES ST -122.412597  37.783932 2008-10-01 14:00:00
# 1            CAPP ST / 17TH ST -122.418486  37.763495 2008-10-01 15:28:00
# 2  SOUTH VAN NESS AV / 20TH ST -122.416873  37.758764 2008-10-01 15:54:00
# 3       500.0 Block of MAIN ST -122.409208  37.779767 2008-10-03 22:15:00
# 4       0.0 Block of TAYLOR ST -122.410622  37.782690 2008-10-06 09:59:00
#
#    block_vicinity_x   latlng_datetime  time_vicinity_x  CaseID  \
# 0              3994  4076232.0 3994.0          4076232  290673
# 1              3917  4076249.0 3917.0          4076249  290747
# 2              3908  4076254.0 3908.0          4076254  290769
# 3              3992  4076907.0 3992.0          4076907  292196
# 4              3996  4077623.0 3996.0          4077623  293001
#
#                    Opened                  Closed                 Updated
# 0  10/01/2008 02:00:00 PM  10/04/2008 06:06:00 AM  10/04/2008 06:06:00 AM ...
# 1  10/01/2008 03:28:00 PM  02/24/2009 10:40:00 AM  02/24/2009 10:40:00 AM ...
# 2  10/01/2008 03:52:00 PM  10/23/2008 11:06:00 AM  10/23/2008 11:06:00 AM ...
# 3  10/03/2008 10:18:00 PM  10/06/2008 02:43:00 PM  10/06/2008 02:43:00 PM ...
# 4  10/06/2008 09:56:00 AM  10/07/2008 06:06:00 AM  10/07/2008 06:06:00 AM ...
#
# [5 rows x 36 columns]

# %%
def serious_or_not(row):
    if row['Resolution']=='NONE':
        return 0
    else:
        return 1
    
c['Outcome'] = c.apply(serious_or_not, axis=1)

# %%
c[['Location','Address', 'Category_x', 'Category_y', 'Request Type','Request Details', 'Descript','Resolution','Status','Outcome']].head(5)
# Out:
#                       Location                                       Address  \
# 0           EDDY ST / JONES ST     3145 OCTAVIA ST, SAN FRANCISCO, CA, 94123
# 1            CAPP ST / 17TH ST  3165 WASHINGTON ST, SAN FRANCISCO, CA, 94115
# 2  SOUTH VAN NESS AV / 20TH ST     359 FILLMORE ST, SAN FRANCISCO, CA, 94117
# 3       500.0 Block of MAIN ST         Intersection of LARKIN ST and PINE ST
# 4       0.0 Block of TAYLOR ST       Intersection of 6TH ST and STEVENSON ST
#
#        Category_x                    Category_y  \
# 0  SUSPICIOUS OCC  Street and Sidewalk Cleaning
# 1  OTHER OFFENSES                  Sewer Issues
# 2  OTHER OFFENSES  Street and Sidewalk Cleaning
# 3   LARCENY/THEFT              General Requests
# 4    NON-CRIMINAL  Street and Sidewalk Cleaning
#
#                          Request Type                     Request Details  \
# 0                     Street_Cleaning                           Furniture
# 1                   Side_Sewer_Issues                    Water_coming_out
# 2                     Illegal_Dumping    Oil_paint_other_liquid_spill_wet
# 3  puc - electric - customer_callback  puc - electric - customer_callback
# 4                   Sidewalk_Cleaning                             Garbage
#
#                        Descript         Resolution  Status  Outcome
# 0         SUSPICIOUS OCCURRENCE               NONE  Closed        0
# 1             TRAFFIC VIOLATION      ARREST, CITED  Closed        1
# 2             TRAFFIC VIOLATION      ARREST, CITED  Closed        1
# 3  GRAND THEFT FROM LOCKED AUTO               NONE  Closed        0
# 4  AIDED CASE, MENTAL DISTURBED  PSYCHOPATHIC CASE  Closed        1
#
# [5 rows x 10 columns]

# %%
import numpy
all_cases = c.reindex(np.random.permutation(c.index))

all_test = all_cases[0:all_cases.shape[0]/5]
all_training = all_cases[all_cases.shape[0]/5:]

import nltk, re

def tokenize_descript(row):
    return re.sub("[^\w]", " ",  row['Descript']).split()

# %%
list(all_test.columns.values)
# Out:
# ['Unnamed: 0',
#  'IncidntNum',
#  'Category_x',
#  'Descript',
#  'DayOfWeek',
#  'Date',
#  'Time',
#  'PdDistrict',
#  'Resolution',
#  'Location',
#  'X_x',
#  'Y_x',
#  'DateTime_x',
#  'block_vicinity_x',
#  'latlng_datetime',
#  'time_vicinity_x',
#  'CaseID',
#  'Opened',
#  'Closed',
#  'Updated',
#  'Status',
#  'Responsible Agency',
#  'Category_y',
#  'Request Type',
#  'Request Details',
#  'Address',
#  'Supervisor District',
#  'Neighborhood',
#  'Point',
#  'Source',
#  'Media URL',
#  'DateTime_y',
#  'X_y',
#  'Y_y',
#  'block_vicinity_y',
#  'time_vicinity_y',
#  'Outcome']

# %% [markdown]
# ###Approaches to merge data:
#
# #####Exact matches
#
# 1. Use address for exact match
# 2. Use date and time for exact match
#
# #####Fuzzy matches (this changes the problem. we're trying to see if reports that weren't related could be used for prediction)
#
# 1. Use address - tokenizing
# 2. Use lat and long by setting up a perimeter (to test with multiple parameters) - seems most promising
# 3. Use date and time with a window period
# 4. Use combination of date + time and lat + long with a larger window period for each one
# 5. Use combination of just time with lat + long with larger window periods for lat/long but smaller ones for time
#
# With fuzzy matches, we're likely to have multiple matches. There are 2 things to consider
#
# 1. Should we reduce our 'fuzziness' so that it reduces to maximum number of single matches?
# 2. Is there value in having multiple matches?
# 3. More matches have a higher predictive power

# %% [markdown]
# # Steps taken
#
# 1. Merged all 311 data together from 2008 to 2014 since we only had sfpd from that time range
#     - SFPD Dataset: ~310mb (~1.1 million records)
#     - 311 Dataset: ~140mb (~0.9 million records)
#
# 2. Used Address and Location for matches
#     - Address and Location gave 0 matches (as expected)
#     - Addresses are recorded differently
#
# 3. Used Date and Time for matches
#     - Expected 0 matches since the dates and times were recorded differently
#     - Turned out to have 177076 matches!
#     - I thought we could do something with this data
#     - Looked closely at the data and there was 0 correlation between the addresses. the reports wouldn't make sense (show screenshot)
#     - Decided not to continue down this path as the only meaningiful we would get would be which times of the day was an emergency crime more likely
#
# 4. Use combination of lat/lng and date/time for matches
#     - Matches addresses that were within the same block and exactly the same time
#     - got 1957 matches!
#     - looking at the data though, there was little relation
